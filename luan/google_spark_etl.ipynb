# %%
import os
import sys

os.environ['PYSPARK_PYTHON'] = sys.executable
os.environ['PYSPARK_DRIVER_PYTHON'] = sys.executable

# %%
import requests
import pandas as pd
pd.set_option('max_columns', None)
import pyarrow
import json
from pyspark.sql import SparkSession
import glob
import json
from psycopg2 import connect

# %%
df = pd.read_csv('/project/NameList300.csv')

# %%
df
# Out:
#      Unnamed: 0                          Name  \
# 0             0            Bonoo Indian Tapas
# 1             1                         Hibox
# 2             2  Devine Restaurant Coffee Bar
# 3             3                Scarlett Green
# 4             4                   Indian Room
# ..          ...                           ...
# 295         295       The Foyer At Claridge's
# 296         296                   Il Girasole
# 297         297            Specialist Cellars
# 298         298         The Bull Steak Expert
# 299         299                   Beck's cafe
#
#                                                    URL
# 0    https://www.tripadvisor.com/Restaurant_Review-...
# 1    https://www.tripadvisor.com/Restaurant_Review-...
# 2    https://www.tripadvisor.com/Restaurant_Review-...
# 3    https://www.tripadvisor.com/Restaurant_Review-...
# 4    https://www.tripadvisor.com/Restaurant_Review-...
# ..                                                 ...
# 295  https://www.tripadvisor.com/Restaurant_Review-...
# 296  https://www.tripadvisor.com/Restaurant_Review-...
# 297  https://www.tripadvisor.com/Restaurant_Review-...
# 298  https://www.tripadvisor.com/Restaurant_Review-...
# 299  https://www.tripadvisor.com/Restaurant_Review-...
#
# [300 rows x 3 columns]

# %%
res_list = list(df['Name'])

# %%
list_rest2 = [i.replace("'", "").replace("’", "") for i in res_list]

list_rest2
# Out:
# ['Bonoo Indian Tapas',
#  'Hibox',
#  'Devine Restaurant Coffee Bar',
#  'Scarlett Green',
#  'Indian Room',
#  'Nora Cafe',
#  'Bayleaf Restaurant',
#  'Amrutha Lounge',
#  'Alexander The Great',
#  'Andys Greek Taverna',
#  'Muhib Indian Cuisine',
#  'Chamisse',
#  'Spasso',
#  'Indian Moment',
#  'Taste Of Nawab',
#  'Awesome Thai #Finchley',
#  'Bruce Burgers',
#  'Tanias of Hampstead',
#  'The Park Room',
#  'The Wine Place Covent Garden',
#  'Cafe Parisienne',
#  'Manuels Restaurant and Bar',
#  'The Rajdoot',
#  'The Rajdoot Hampstead',
#  'Launceston Place',
#  'Room 43 Bar & Kitchen',
#  'Paladar',
#  'Dobar',
#  'Eastern Eye Balti House',
#  'O Gourmet Libanais',
#  'Latitude Wimbledon',
#  'Pivaz Hackney',
#  'Lizzies Cucina - Italian Restaurant',
#  'Fugitive Motel',
#  'The Prince of Wales',
#  'Yum Sa',
#  'Wild Thyme',
#  'Cafe de Provence',
#  'Bebs Kitchen',
#  'Almas Restaurant',
#  'The Hampshire',
#  'Brick Lane Brasserie',
#  'Iznik',
#  'The Lounge Cafe',
#  'Cafe Amisha',
#  '28-50 Wine Workshop & Kitchen South Kensington',
#  'Core by Clare Smyth',
#  'London Shell Co. Aboard The Prince Regent',
#  'Yuu Kitchen',
#  'LAngolo Bianco',
#  'Bar 61 Restaurant',
#  'Figo Leyton',
#  '215 Hackney',
#  'The Golden Chippy',
#  'Hiba Street',
#  'Amber Restaurant',
#  'Indian Lounge',
#  'The Hayden',
#  'The Cocktail Trading Company',
#  'The Chelsea Corner',
#  'Oliveira Kitchen',
#  'The Banc',
#  'The Jasmine by Spice Nouv-Oh!',
#  'Sanjugo London',
#  'Standard Balti House - Bricklanes Finest',
#  'Zeret Kitchen',
#  'Tower Tandoori',
#  'The Spice Indian Restaurant',
#  'Terra Rossa',
#  'Bengal Village - Best of Brick Lane',
#  'Richards Kitchen',
#  'Magic Falafel',
#  'KataKata',
#  'Flour To The People!',
#  'Sitara',
#  'TOKii',
#  'The Clink Restaurant',
#  'MAP Maison',
#  'Oi Vita Pizzeria',
#  'The Shell',
#  'Bella Roma - Italian Restaurant',
#  'Mildreds Camden',
#  'Liman Restaurant',
#  'Radicals and Victuallers',
#  'The Famous Curry Bazaar',
#  'Daphne Restaurant',
#  'Nonna Selena Pizzeria',
#  'The Prince of Greenwich Pub',
#  'E Pellicci',
#  'Fishcotheque',
#  'B Bagel Bakery Bar',
#  'Knife Restaurant',
#  'Osteria Napoletana',
#  'Iran Restaurant',
#  'Moira Restaurant',
#  'Humble Grape Liverpool Street',
#  'Llerena. Iberico Tapas Bar',
#  'Revolution Bar Clapham High Street',
#  'Chez Antoinette Victoria',
#  'The Monsoon',
#  'Osteria Romana',
#  'Chez Abir Restaurant',
#  'Alcedo Bistro & Bar',
#  'Tonis Amalfi',
#  'Sushi Tetsu',
#  'Barge East Restaurant',
#  'Awesome Thai #Barnes',
#  'Lentil',
#  'Nepal Authentic Dining',
#  'Anjanaas',
#  'taNgia',
#  'Wassouf Lounge',
#  'Indian Express, West Kensington',
#  'Fiddies Italian Kitchen',
#  'Mio Restaurant',
#  'Filika Restaurant',
#  'Morso Abbey Road',
#  'Yucca',
#  'Rock Star Sushi Bar',
#  'The Five Fields',
#  'The Great Chase London',
#  'Cafe Van Gogh',
#  'Buenos Aires Argentine Steakhouse',
#  'Monkey Temple',
#  'Shahi Pakwaan',
#  'Memories of India Kensington',
#  'Fine Foods',
#  'Tomo Pizzeria & Restaurant',
#  'Home SW15',
#  'Treves & Hyde',
#  'Hard Rock Cafe Piccadilly Circus',
#  'EaTurkish',
#  'The Gojk',
#  'Cirrik 19 Numara Bos',
#  'Galvin La Chapelle',
#  'Sergios',
#  'The Ledbury',
#  'Blacklock Soho',
#  'Chojo',
#  'Limin',
#  'Sky Pod Bar',
#  'Hazara',
#  'Caminata',
#  'Trattoria Raffaele',
#  'Sams Riverside',
#  'Wolkite restaurant',
#  'Venerdi',
#  'JW Steakhouse',
#  'The Vincent Rooms Brasserie, Bar & Escoffier Restaurant',
#  'Little India',
#  'Fast Break',
#  'Humble Grape Battersea',
#  'Palms of Goa',
#  'Peninsula Restaurant',
#  'Steak & Co. Garrick Street Covent Garden',
#  'Ormer Mayfair',
#  'Pentolina',
#  'Humble Grape Islington',
#  'Azou',
#  'Blacklock Shoreditch',
#  'Little Wonder Cafe',
#  'Lord Wargrave',
#  'Da Mario Covent Garden',
#  'Alexandrie Restaurant',
#  'Kamasutra Indian Restaurant',
#  'Grato',
#  'Frog By Adam Handling',
#  'The Peasant',
#  'Tanakatsu',
#  'Rudys Neapolitan Pizza',
#  'Fishers Restaurant & Takeaway',
#  'Capeesh',
#  'La Piccola Deli Pasticceria',
#  'Leicester Square Kitchen',
#  'Sunday Champagne Brunch at The Landmark London',
#  'Chez Elles Bistroquet',
#  'Wulf & Lamb - Chelsea',
#  'Steak & Co Piccadilly Circus',
#  'Apres Food Co.',
#  'Bel Canto Restaurant',
#  'CERU',
#  'May Fair Kitchen',
#  'Mangia Bene',
#  'Bloomsbury Street Kitchen',
#  '28-50 Wine Bar & Kitchen Covent Garden',
#  'Miller & Carter',
#  'Bella Vita',
#  'AW Restaurant',
#  'Revolution Putney',
#  'Pane Cunzato - Pizza & more',
#  'Anglo',
#  'The Blacksmiths Arms',
#  'Salut!',
#  'Midpoint Restaurant',
#  'Blacklock City',
#  'Tom Simmons - Tower Bridge',
#  'Taste of India',
#  'Dalloway Terrace',
#  'Dhaba@49',
#  'Augustine Kitchen',
#  'Medlar',
#  'El Inca Plebeyo',
#  'Volare',
#  'Laurent at Cafe Royal',
#  'Khans of Kensington',
#  'Purezza Camden',
#  'Chez Bruce',
#  'Bella Italia',
#  'Loro di Napoli',
#  'Las Iguanas The O2',
#  'Luna Nuova',
#  'Rossella',
#  'Rodfai Thai street food',
#  'La Trompette',
#  'Jolie Chelsea',
#  'The Petite Coree',
#  'New London Cafe',
#  'Scully St Jamess',
#  'Boro Bistro',
#  'Hungry Turtle',
#  'Myrtle Restaurant',
#  'Humble Grape',
#  'Wiltons',
#  'Cappadocia',
#  'Arro Coffee - Bayswater',
#  'Lorne Restaurant',
#  'Zala grill',
#  'Gloria',
#  'Ciullosteria',
#  'Luna Rossa',
#  'Ishtar',
#  'Monmouth Kitchen, Covent Garden',
#  'Mestizo',
#  'Baileys Fish and Chips',
#  'Plate Restaurant, Bar and Bake',
#  'Double Js Cafe',
#  'Senzala Creperie',
#  'The Oystermen Seafood Bar & Kitchen',
#  'Cibo',
#  'Pizza Sophia',
#  'Kahani',
#  'Salento',
#  'Trinity Restaurant',
#  'Everest Inn - Blackheath Village',
#  'Niche Gluten-free Dining',
#  'Turtle Bay - Brixton',
#  'Kazan Restaurant',
#  'Kona',
#  'Kings Stores',
#  'Falafel Feast',
#  'Steak & Co. Leicester Square Charing Cross',
#  'Town House',
#  'Pera Restaurant islington',
#  'The Wilmington',
#  'Companero',
#  'Lanes of London',
#  'Maurizio Barca',
#  'Pizzetta Pizza',
#  'The Victoria',
#  'Goodman Mayfair',
#  'Le Petit Citron',
#  'Mosob Restaurant',
#  'The White Onion',
#  'Constancia',
#  'The Bar at The Dorchester',
#  'Ottos',
#  'Smiths',
#  'Mountain View Restaurant Greenwich',
#  'Pizza Pilgrims',
#  'Panas Gurkha Restaurant',
#  'Bella Italia',
#  'Blighty Cafe (Finsbury Park)',
#  'Nipa Thai Restaurant',
#  'Dishoom Carnaby',
#  'Dulce Cafe',
#  'Casa Tua Camden',
#  'Seven Park Place By William Drabble',
#  'The Swan',
#  'Fish Central',
#  'The India - Best of The City',
#  'The Rosebery',
#  'Flat Iron London Bridge',
#  'Chettinad Restaurant',
#  'The Pride of Spitalfields',
#  'The Little Taperia',
#  'Sapori Cafe and Restaurant',
#  'Bar Remo',
#  'Pure Indian Cooking',
#  'Steak And Lobster Warren Street',
#  'Union Tavern',
#  'Flora Indica',
#  'Chisou Japanese Restaurant',
#  'Popolo Shoreditch',
#  'Kibele Restaurant & Bar',
#  'Light of India',
#  'The Foyer At Claridges',
#  'Il Girasole',
#  'Specialist Cellars',
#  'The Bull Steak Expert',
#  'Becks cafe']

# %%
# function to get restaurant information using api and save into json
def get_data(restaurant):
    url = f"https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input={restaurant}%20London&inputtype=textquery&fields=place_id&key=apikey"
    
    payload={}
    headers = {}
    response = requests.get(url, headers=headers, data=payload)

    restaurant_id = json.loads(response.text)
    rest = restaurant_id['candidates'][0]['place_id']
    
    url = f"https://maps.googleapis.com/maps/api/place/details/json?place_id={rest}&key=apikey"
    
    payload={}
    headers = {}

    response = requests.request("GET", url, headers=headers, data=payload)
    
    json_data = response.json()
    
    google_id = {'google_id' : rest}
    
    json_data.update(google_id)
    
    res_name = json_data['result']['name']
    
    with open(f"/project/json/{res_name}.json", "w+") as json_file:
        json_string = json.dumps(json_data, sort_keys=True, indent=4)
        json_file.write(json_string)
    print('request completed')

# %%
for i in list_rest2:
    try:
        get_data(i)
    except:
        pass
# Out:
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed
# request completed

# %%
pathlist = []

# %%
for filepath in glob.iglob('/project/json/*.json'):
    pathlist.append(filepath)

# %%
pathlist
# Out:
# ['/project/json/Fishcotheque.json',
#  '/project/json/The Pride of Spitalfields London.json',
#  '/project/json/The Clink Brixton.json',
#  '/project/json/Muhib Indian cuisine.json',
#  '/project/json/28-50 Wine Workshop & Kitchen.json',
#  '/project/json/Dobar.json',
#  '/project/json/Featherblade Steak Restaurant.json',
#  '/project/json/Bel Canto.json',
#  '/project/json/Bengal Village - Best of Brick Lane.json',
#  '/project/json/The Ledbury.json',
#  '/project/json/Azou Restaurant.json',
#  '/project/json/The Great Chase.json',
#  '/project/json/Bar Remo.json',
#  '/project/json/Wolkite restaurant.json',
#  "/project/json/Sam's Riverside.json",
#  '/project/json/Luna Rossa.json',
#  '/project/json/Peninsula Restaurant.json',
#  '/project/json/Kahani Restaurant Sloane Square.json',
#  '/project/json/EaTurkish.json',
#  '/project/json/Indian Room.json',
#  '/project/json/Lord Wargrave.json',
#  '/project/json/Lorne.json',
#  '/project/json/Core by Clare Smyth.json',
#  '/project/json/The Bull Steak Expert.json',
#  '/project/json/Chez Abir Lebanese Restaurant.json',
#  '/project/json/TOKii.json',
#  '/project/json/The India - Best of The City.json',
#  '/project/json/Buenos Aires.json',
#  '/project/json/Nonna Selena Pizzeria.json',
#  '/project/json/Ciullosteria.json',
#  '/project/json/Shahi Pakwaan.json',
#  '/project/json/Zeret Kitchen.json',
#  '/project/json/Champagne Brunch at The Landmark London.json',
#  '/project/json/Amber Restaurant.json',
#  '/project/json/Figo Leyton.json',
#  '/project/json/Trattoria Raffaele.json',
#  '/project/json/Little Wonder Cafe.json',
#  '/project/json/The Rosebery.json',
#  "/project/json/Lizzie's Cucina - Italian Restaurant.json",
#  '/project/json/Awesome Thai #Finchley.json',
#  '/project/json/Kings Stores.json',
#  '/project/json/TANAKATSU.json',
#  '/project/json/Galvin La Chapelle.json',
#  '/project/json/Humble Grape.json',
#  '/project/json/Amrutha Lounge.json',
#  '/project/json/Flora Indica.json',
#  '/project/json/Magic Falafel.json',
#  '/project/json/Mildreds Camden.json',
#  '/project/json/Radicals And Victuallers.json',
#  '/project/json/Chisou Sushi and Izakaya.json',
#  '/project/json/The Rajdoot.json',
#  '/project/json/Prince of Wales, Brixton.json',
#  '/project/json/Fugitive Motel.json',
#  '/project/json/Il Girasole restaurant.json',
#  '/project/json/Bella Vita.json',
#  '/project/json/The Jasmine By Spice Nouv-Oh!.json',
#  '/project/json/taNgia.json',
#  '/project/json/Sanjugo Shoreditch.json',
#  '/project/json/Oi Vita Pizzeria.json',
#  '/project/json/Pivaz.json',
#  '/project/json/Compañero.json',
#  '/project/json/Rock Star Sushi Bar.json',
#  '/project/json/The Union Tavern.json',
#  '/project/json/Seven Park Place by William Drabble.json',
#  '/project/json/Liman Restaurant.json',
#  '/project/json/The Swan.json',
#  '/project/json/Tower Tandoori Restaurant.json',
#  '/project/json/Casa Tua Camden.json',
#  '/project/json/Cafe de Provence.json',
#  '/project/json/Pentolina.json',
#  '/project/json/Frog by Adam Handling Restaurant Covent Garden.json',
#  '/project/json/The Prince of Greenwich Pub.json',
#  '/project/json/Osteria Napoletana.json',
#  '/project/json/Hibox.json',
#  '/project/json/Monkey Temple.json',
#  '/project/json/Miller Group Limited.json',
#  '/project/json/Salut! Restaurant Islington.json',
#  '/project/json/The Monsoon.json',
#  '/project/json/B Bagel Fulham.json',
#  '/project/json/E Pellicci.json',
#  '/project/json/The Five Fields.json',
#  '/project/json/The Hampshire.json',
#  '/project/json/Bebs Kitchen.json',
#  '/project/json/The Famous Curry Bazaar.json',
#  '/project/json/CERU South Kensington.json',
#  '/project/json/Light Of India.json',
#  '/project/json/Bella Italia - Cranbourn Street.json',
#  '/project/json/Flour to the People!.json',
#  '/project/json/Wassouf Lounge.json',
#  '/project/json/Pizza Sophia.json',
#  '/project/json/Zala grill.json',
#  '/project/json/Lanes of London.json',
#  '/project/json/Katakata.json',
#  '/project/json/London Shell Co..json',
#  '/project/json/Wolf+Spoon.json',
#  '/project/json/Turtle Bay Brixton.json',
#  '/project/json/Panas Gurkha Restaurant.json',
#  '/project/json/Kazan Restaurant.json',
#  '/project/json/Gloria.json',
#  '/project/json/Pane Cunzato - Italian Pizza Restaurant.json',
#  '/project/json/Las Iguanas - London - The O2.json',
#  '/project/json/Falafel Feast.json',
#  '/project/json/La Piccola Deli Pasticceria.json',
#  '/project/json/Treves (UK) Ltd.json',
#  "/project/json/Double J'S Cafe.json",
#  '/project/json/Niche Gluten-free Dining.json',
#  '/project/json/Caminata.json',
#  '/project/json/Sapori.json',
#  '/project/json/Nepal Authentic Dining.json',
#  '/project/json/Nipa Thai.json',
#  '/project/json/Fine Foods - Locanda del Melo.json',
#  '/project/json/Terra Rossa.json',
#  '/project/json/Alcedo Bistro & Bar.json',
#  '/project/json/Le Petit Citron.json',
#  '/project/json/Alexandrie Restaurant.json',
#  '/project/json/Chez Antoinette Victoria.json',
#  '/project/json/Mountain view.json',
#  '/project/json/Golden Chippy.json',
#  '/project/json/Tonis Amalfi Italian Restaurant & Pizzeria.json',
#  '/project/json/Wild Thyme Cafe.json',
#  '/project/json/Popolo Shoreditch.json',
#  '/project/json/The Bar.json',
#  '/project/json/Flat Iron London Bridge.json',
#  '/project/json/Myrtle Restaurant.json',
#  '/project/json/Cirrik 19 Numara Bos.json',
#  '/project/json/The Victoria, Paddington.json',
#  '/project/json/Purezza Camden.json',
#  '/project/json/The Blacksmiths Arms.json',
#  '/project/json/Cafe Van Gogh.json',
#  '/project/json/Daphne Restaurant.json',
#  '/project/json/Palms of Goa.json',
#  '/project/json/Kona.json',
#  '/project/json/The Wilmington.json',
#  '/project/json/Bonoo Indian Tapas.json',
#  "/project/json/Limin' Beach Club.json",
#  '/project/json/Home SW15.json',
#  '/project/json/Après Food for Body and Mind.json',
#  '/project/json/Mestizo Mexican Restaurant.json',
#  '/project/json/The Shell.json',
#  '/project/json/Jolie - French Restaurant, Brunch & Terrace.json',
#  '/project/json/Pure Indian cooking.json',
#  '/project/json/Morso Abbey Road.json',
#  '/project/json/Filika Restaurant.json',
#  "/project/json/Otto's French Restaurant London.json",
#  '/project/json/Spasso.json',
#  '/project/json/Luna Nuova.json',
#  '/project/json/The Wine Place Covent Garden.json',
#  '/project/json/Capeesh.json',
#  '/project/json/Yuu Kitchen.json',
#  '/project/json/The Oystermen Seafood Bar & Kitchen.json',
#  '/project/json/Andy’s Greek Taverna.json',
#  '/project/json/Mosob Restaurant.json',
#  '/project/json/Maurizio Barca.json',
#  '/project/json/Wiltons Restaurant.json',
#  '/project/json/Baileys.json',
#  '/project/json/Volare.json',
#  '/project/json/Café Amisha.json',
#  '/project/json/Chez Elles Bistroquet.json',
#  '/project/json/Richard’s Kitchen.json',
#  '/project/json/Oliveira Kitchen.json',
#  "/project/json/Khan's of Kensington.json",
#  '/project/json/Taste of India NW1.json',
#  '/project/json/La Trompette.json',
#  '/project/json/Anglo.json',
#  '/project/json/Moira Restaurant.json',
#  "/project/json/Manuel's Italian and Mediterranean Restaurant and Bar.json",
#  '/project/json/Sushi Tetsu.json',
#  '/project/json/Standard Balti House.json',
#  '/project/json/Tom Simmons - Tower Bridge.json',
#  '/project/json/The Petite Corée.json',
#  '/project/json/AW Restaurant.json',
#  '/project/json/Alexander The Great Restaurant.json',
#  '/project/json/Launceston Place.json',
#  '/project/json/Bayleaf Restaurant.json',
#  '/project/json/Chettinad Restaurant.json',
#  '/project/json/Ô Gourmet Libanais.json',
#  '/project/json/Cappadocia Cafe & Bistro.json',
#  '/project/json/Cafe Parisienne.json',
#  '/project/json/Grato.json',
#  '/project/json/JW Steakhouse.json',
#  '/project/json/Dhaba@49.json',
#  '/project/json/Anjanaas.json',
#  '/project/json/Da Mario Covent Garden.json',
#  '/project/json/Laurent at Café Royal.json',
#  "/project/json/Scully St James's.json",
#  '/project/json/The Peasant.json',
#  '/project/json/Indian Express.json',
#  '/project/json/Monmouth Kitchen.json',
#  "/project/json/Rudy's Neapolitan Pizza - Soho.json",
#  '/project/json/Venerdi.json',
#  '/project/json/Indian Lounge.json',
#  '/project/json/Hard Rock Cafe.json',
#  '/project/json/Midpoint Restaurant.json',
#  '/project/json/Knife.json',
#  '/project/json/Cibo.json',
#  '/project/json/Chamisse.json',
#  '/project/json/Hungry Turtle.json',
#  '/project/json/Senzala Creperie.json',
#  '/project/json/Latitude Restaurant.json',
#  '/project/json/The Banc.json',
#  '/project/json/RodFai.json',
#  '/project/json/Bar 61 Restaurant.json',
#  '/project/json/The Spice.json',
#  '/project/json/Kamasutra Indian Restaurant.json',
#  '/project/json/Kibele Restaurant.json',
#  '/project/json/Rossella.json',
#  '/project/json/MAP Maison.json',
#  '/project/json/Osteria Romana.json',
#  '/project/json/The Sitara.json',
#  '/project/json/Food at Fishers Ltd.json',
#  '/project/json/Paladar.json',
#  '/project/json/Medlar.json',
#  '/project/json/El Inca Plebeyo Restaurant.json',
#  '/project/json/Boro Bistro.json',
#  '/project/json/Iznik.json',
#  '/project/json/Eastern Eye Balti House.json',
#  '/project/json/The Little Taperia.json',
#  '/project/json/Pizza Pilgrims.json',
#  '/project/json/The White Onion.json',
#  '/project/json/Bruce Burgers.json',
#  '/project/json/215 Hackney.json',
#  '/project/json/Dean Street Townhouse.json',
#  '/project/json/Brick Lane Brasserie.json',
#  '/project/json/Bloomsbury Street Kitchen.json',
#  '/project/json/Goodman - Mayfair.json',
#  '/project/json/Lentil Nepalese, Indian Cusine.json',
#  '/project/json/Blighty - a very British cafe.json',
#  '/project/json/Pizzetta.json',
#  '/project/json/PERA Bistro.json',
#  '/project/json/Ishtar.json',
#  '/project/json/Memories of India Kensington.json',
#  '/project/json/De Vine.json',
#  '/project/json/Revolution London - Clapham High St.json',
#  '/project/json/Augustine Kitchen.json',
#  '/project/json/The Rajdoot Hampstead.json',
#  '/project/json/Chez Bruce.json',
#  '/project/json/Arro Coffee - Bayswater.json',
#  '/project/json/Salento Restaurant - Bar - pizzeria - Italian food grocery -.json',
#  '/project/json/Constancia.json',
#  '/project/json/Dalloway Terrace.json',
#  '/project/json/Scarlett Green.json',
#  '/project/json/Little India.json',
#  '/project/json/Llerena.json',
#  '/project/json/Fish Central.json',
#  '/project/json/Smiths of Wapping.json',
#  '/project/json/Hazara Restaurants.json',
#  "/project/json/Tania's Of Hampstead.json",
#  '/project/json/Dishoom Carnaby.json',
#  "/project/json/L'oro di Napoli Ealing.json",
#  '/project/json/Blacklock Shoreditch.json',
#  '/project/json/The Foyer & Reading Room.json',
#  "/project/json/Sergio's.json",
#  '/project/json/ChoJo.json',
#  '/project/json/Mio Restaurant bar.json',
#  '/project/json/New London Cafe.json',
#  '/project/json/Iran Restaurant.json',
#  '/project/json/Hiba Street Food.json',
#  '/project/json/Fast Break.json',
#  '/project/json/Everest Inn.json',
#  '/project/json/Trinity.json',
#  '/project/json/Revolution London - Putney.json',
#  '/project/json/Indian Moment.json',
#  '/project/json/Tomo Pizzeria-Restaurant.json',
#  '/project/json/Humble Grape Islington.json',
#  '/project/json/Yum Sa.json',
#  '/project/json/Sky Pod Bar.json',
#  '/project/json/Yucca London.json',
#  '/project/json/Humble Grape Liverpool Street.json',
#  "/project/json/Fiddie's.json",
#  '/project/json/The Lounge Cafe Wembley.json',
#  '/project/json/Plate Restaurant.json',
#  '/project/json/Taste of Nawab.json',
#  '/project/json/Dulce Coffee London.json',
#  '/project/json/NORA CAFE.json',
#  '/project/json/The Chelsea Corner.json',
#  '/project/json/Room 43 bar Clapham.json',
#  '/project/json/The Gojk Restaurant Lounge.json',
#  "/project/json/L'Angolo Bianco.json",
#  '/project/json/The Cocktail Trading Co. Brick Lane.json',
#  '/project/json/Blacklock City.json',
#  '/project/json/May Fair Kitchen.json',
#  '/project/json/Blacklock Soho.json',
#  '/project/json/Steak & Lobster Warren Street.json',
#  '/project/json/Specialist Cellars.json',
#  '/project/json/Vincent Rooms.json',
#  '/project/json/Barge East Restaurant.json',
#  '/project/json/Ormer Mayfair Restaurant.json',
#  '/project/json/Almas Restaurant.json',
#  '/project/json/Leicester Square Kitchen.json',
#  '/project/json/Becks cafe.json',
#  '/project/json/The Hayden Pub & Rooms.json',
#  '/project/json/Bella Roma - Italian Restaurant.json',
#  '/project/json/Afternoon Tea at The Park Room.json',
#  '/project/json/Mangia Bene.json']

# %%
# create sparksession
spark = SparkSession \
    .builder \
    .appName("jsontoparquet") \
    .getOrCreate()

# %%
for i in pathlist:
    try:
        json_df = spark.read.json(i, multiLine=True)
        json_df.write.parquet(f"/project/parquet/{i[14:-5]}.parquet")
    except:
        pass

# %%
parquet_filepath = []

# %%
for filepath in glob.iglob('/project/parquet/*.parquet'):
    parquet_filepath.append(filepath)

# %%
parquet_filepath
# Out:
# ['/project/parquet/Champagne Brunch at The Landmark London.parquet',
#  '/project/parquet/Zeret Kitchen.parquet',
#  '/project/parquet/Shahi Pakwaan.parquet',
#  '/project/parquet/Ciullosteria.parquet',
#  '/project/parquet/Buenos Aires.parquet',
#  '/project/parquet/Nonna Selena Pizzeria.parquet',
#  '/project/parquet/The India - Best of The City.parquet',
#  '/project/parquet/TOKii.parquet',
#  '/project/parquet/Trattoria Raffaele.parquet',
#  '/project/parquet/Figo Leyton.parquet',
#  '/project/parquet/Amber Restaurant.parquet',
#  '/project/parquet/Chez Abir Lebanese Restaurant.parquet',
#  '/project/parquet/The Bull Steak Expert.parquet',
#  '/project/parquet/Core by Clare Smyth.parquet',
#  '/project/parquet/Lorne.parquet',
#  '/project/parquet/EaTurkish.parquet',
#  '/project/parquet/Indian Room.parquet',
#  '/project/parquet/Lord Wargrave.parquet',
#  '/project/parquet/The Ledbury.parquet',
#  '/project/parquet/Bel Canto.parquet',
#  '/project/parquet/Bengal Village - Best of Brick Lane.parquet',
#  '/project/parquet/Dobar.parquet',
#  '/project/parquet/Featherblade Steak Restaurant.parquet',
#  '/project/parquet/Fishcotheque.parquet',
#  '/project/parquet/The Pride of Spitalfields London.parquet',
#  '/project/parquet/The Clink Brixton.parquet',
#  '/project/parquet/Muhib Indian cuisine.parquet',
#  '/project/parquet/28-50 Wine Workshop & Kitchen.parquet',
#  '/project/parquet/Kahani Restaurant Sloane Square.parquet',
#  '/project/parquet/Peninsula Restaurant.parquet',
#  '/project/parquet/Luna Rossa.parquet',
#  "/project/parquet/Sam's Riverside.parquet",
#  '/project/parquet/Azou Restaurant.parquet',
#  '/project/parquet/Bar Remo.parquet',
#  '/project/parquet/The Great Chase.parquet',
#  '/project/parquet/Wolkite restaurant.parquet',
#  '/project/parquet/Bella Vita.parquet',
#  '/project/parquet/Il Girasole restaurant.parquet',
#  '/project/parquet/taNgia.parquet',
#  '/project/parquet/The Jasmine By Spice Nouv-Oh!.parquet',
#  '/project/parquet/Sanjugo Shoreditch.parquet',
#  '/project/parquet/Fugitive Motel.parquet',
#  '/project/parquet/Prince of Wales, Brixton.parquet',
#  '/project/parquet/Radicals And Victuallers.parquet',
#  '/project/parquet/Chisou Sushi and Izakaya.parquet',
#  '/project/parquet/The Rajdoot.parquet',
#  '/project/parquet/Kings Stores.parquet',
#  '/project/parquet/TANAKATSU.parquet',
#  '/project/parquet/Galvin La Chapelle.parquet',
#  "/project/parquet/Lizzie's Cucina - Italian Restaurant.parquet",
#  '/project/parquet/The Rosebery.parquet',
#  '/project/parquet/Awesome Thai #Finchley.parquet',
#  '/project/parquet/Little Wonder Cafe.parquet',
#  '/project/parquet/Magic Falafel.parquet',
#  '/project/parquet/Mildreds Camden.parquet',
#  '/project/parquet/Flora Indica.parquet',
#  '/project/parquet/Humble Grape.parquet',
#  '/project/parquet/Amrutha Lounge.parquet',
#  '/project/parquet/Wolf+Spoon.parquet',
#  '/project/parquet/Turtle Bay Brixton.parquet',
#  '/project/parquet/Lanes of London.parquet',
#  '/project/parquet/Katakata.parquet',
#  '/project/parquet/London Shell Co..parquet',
#  '/project/parquet/Wassouf Lounge.parquet',
#  '/project/parquet/Pizza Sophia.parquet',
#  '/project/parquet/Zala grill.parquet',
#  '/project/parquet/CERU South Kensington.parquet',
#  '/project/parquet/Bella Italia - Cranbourn Street.parquet',
#  '/project/parquet/Light Of India.parquet',
#  '/project/parquet/Flour to the People!.parquet',
#  '/project/parquet/The Five Fields.parquet',
#  '/project/parquet/The Hampshire.parquet',
#  '/project/parquet/Bebs Kitchen.parquet',
#  '/project/parquet/The Famous Curry Bazaar.parquet',
#  '/project/parquet/Oi Vita Pizzeria.parquet',
#  '/project/parquet/Pivaz.parquet',
#  '/project/parquet/Compañero.parquet',
#  '/project/parquet/Seven Park Place by William Drabble.parquet',
#  '/project/parquet/The Union Tavern.parquet',
#  '/project/parquet/Rock Star Sushi Bar.parquet',
#  '/project/parquet/Cafe de Provence.parquet',
#  '/project/parquet/Casa Tua Camden.parquet',
#  '/project/parquet/Liman Restaurant.parquet',
#  '/project/parquet/Tower Tandoori Restaurant.parquet',
#  '/project/parquet/The Swan.parquet',
#  '/project/parquet/The Prince of Greenwich Pub.parquet',
#  '/project/parquet/Frog by Adam Handling Restaurant Covent Garden.parquet',
#  '/project/parquet/Osteria Napoletana.parquet',
#  '/project/parquet/Hibox.parquet',
#  '/project/parquet/Pentolina.parquet',
#  '/project/parquet/Monkey Temple.parquet',
#  '/project/parquet/Salut! Restaurant Islington.parquet',
#  '/project/parquet/Miller Group Limited.parquet',
#  '/project/parquet/The Monsoon.parquet',
#  '/project/parquet/B Bagel Fulham.parquet',
#  '/project/parquet/E Pellicci.parquet',
#  '/project/parquet/Flat Iron London Bridge.parquet',
#  '/project/parquet/Myrtle Restaurant.parquet',
#  '/project/parquet/Cirrik 19 Numara Bos.parquet',
#  '/project/parquet/The Victoria, Paddington.parquet',
#  '/project/parquet/The Bar.parquet',
#  '/project/parquet/Popolo Shoreditch.parquet',
#  '/project/parquet/Wild Thyme Cafe.parquet',
#  '/project/parquet/Tonis Amalfi Italian Restaurant & Pizzeria.parquet',
#  '/project/parquet/Alcedo Bistro & Bar.parquet',
#  '/project/parquet/Terra Rossa.parquet',
#  '/project/parquet/Mountain view.parquet',
#  '/project/parquet/Golden Chippy.parquet',
#  '/project/parquet/Chez Antoinette Victoria.parquet',
#  '/project/parquet/Le Petit Citron.parquet',
#  '/project/parquet/Alexandrie Restaurant.parquet',
#  '/project/parquet/Kazan Restaurant.parquet',
#  '/project/parquet/Panas Gurkha Restaurant.parquet',
#  "/project/parquet/Double J'S Cafe.parquet",
#  '/project/parquet/Niche Gluten-free Dining.parquet',
#  '/project/parquet/Las Iguanas - London - The O2.parquet',
#  '/project/parquet/Falafel Feast.parquet',
#  '/project/parquet/La Piccola Deli Pasticceria.parquet',
#  '/project/parquet/Treves (UK) Ltd.parquet',
#  '/project/parquet/Pane Cunzato - Italian Pizza Restaurant.parquet',
#  '/project/parquet/Gloria.parquet',
#  '/project/parquet/Caminata.parquet',
#  '/project/parquet/Sapori.parquet',
#  '/project/parquet/Nepal Authentic Dining.parquet',
#  '/project/parquet/Nipa Thai.parquet',
#  '/project/parquet/Fine Foods - Locanda del Melo.parquet',
#  '/project/parquet/Taste of India NW1.parquet',
#  '/project/parquet/Oliveira Kitchen.parquet',
#  "/project/parquet/Khan's of Kensington.parquet",
#  '/project/parquet/Richard’s Kitchen.parquet',
#  '/project/parquet/Chez Elles Bistroquet.parquet',
#  '/project/parquet/Standard Balti House.parquet',
#  '/project/parquet/Tom Simmons - Tower Bridge.parquet',
#  '/project/parquet/AW Restaurant.parquet',
#  '/project/parquet/The Petite Corée.parquet',
#  '/project/parquet/Alexander The Great Restaurant.parquet',
#  '/project/parquet/Launceston Place.parquet',
#  '/project/parquet/Anglo.parquet',
#  "/project/parquet/Manuel's Italian and Mediterranean Restaurant and Bar.parquet",
#  '/project/parquet/Moira Restaurant.parquet',
#  '/project/parquet/Sushi Tetsu.parquet',
#  '/project/parquet/La Trompette.parquet',
#  '/project/parquet/Andy’s Greek Taverna.parquet',
#  '/project/parquet/Café Amisha.parquet',
#  '/project/parquet/Volare.parquet',
#  '/project/parquet/Baileys.parquet',
#  '/project/parquet/Wiltons Restaurant.parquet',
#  '/project/parquet/Mosob Restaurant.parquet',
#  '/project/parquet/Maurizio Barca.parquet',
#  '/project/parquet/Capeesh.parquet',
#  '/project/parquet/The Wine Place Covent Garden.parquet',
#  '/project/parquet/Yuu Kitchen.parquet',
#  '/project/parquet/The Oystermen Seafood Bar & Kitchen.parquet',
#  '/project/parquet/Morso Abbey Road.parquet',
#  '/project/parquet/Filika Restaurant.parquet',
#  "/project/parquet/Otto's French Restaurant London.parquet",
#  '/project/parquet/Spasso.parquet',
#  '/project/parquet/Luna Nuova.parquet',
#  '/project/parquet/Daphne Restaurant.parquet',
#  '/project/parquet/Palms of Goa.parquet',
#  '/project/parquet/Kona.parquet',
#  '/project/parquet/Cafe Van Gogh.parquet',
#  '/project/parquet/The Blacksmiths Arms.parquet',
#  '/project/parquet/Purezza Camden.parquet',
#  '/project/parquet/Jolie - French Restaurant, Brunch & Terrace.parquet',
#  '/project/parquet/Pure Indian cooking.parquet',
#  '/project/parquet/Bonoo Indian Tapas.parquet',
#  '/project/parquet/The Wilmington.parquet',
#  '/project/parquet/The Shell.parquet',
#  '/project/parquet/Mestizo Mexican Restaurant.parquet',
#  '/project/parquet/Après Food for Body and Mind.parquet',
#  "/project/parquet/Limin' Beach Club.parquet",
#  '/project/parquet/Home SW15.parquet',
#  '/project/parquet/The Sitara.parquet',
#  '/project/parquet/Paladar.parquet',
#  '/project/parquet/Food at Fishers Ltd.parquet',
#  '/project/parquet/MAP Maison.parquet',
#  '/project/parquet/Osteria Romana.parquet',
#  '/project/parquet/The Banc.parquet',
#  '/project/parquet/Latitude Restaurant.parquet',
#  '/project/parquet/Kamasutra Indian Restaurant.parquet',
#  '/project/parquet/The Spice.parquet',
#  '/project/parquet/Rossella.parquet',
#  '/project/parquet/Kibele Restaurant.parquet',
#  '/project/parquet/RodFai.parquet',
#  '/project/parquet/Bar 61 Restaurant.parquet',
#  '/project/parquet/The White Onion.parquet',
#  '/project/parquet/The Little Taperia.parquet',
#  '/project/parquet/Pizza Pilgrims.parquet',
#  '/project/parquet/Boro Bistro.parquet',
#  '/project/parquet/Iznik.parquet',
#  '/project/parquet/El Inca Plebeyo Restaurant.parquet',
#  '/project/parquet/Medlar.parquet',
#  '/project/parquet/Eastern Eye Balti House.parquet',
#  '/project/parquet/Cibo.parquet',
#  '/project/parquet/Chamisse.parquet',
#  '/project/parquet/Hungry Turtle.parquet',
#  '/project/parquet/Senzala Creperie.parquet',
#  '/project/parquet/Midpoint Restaurant.parquet',
#  '/project/parquet/Knife.parquet',
#  '/project/parquet/Venerdi.parquet',
#  '/project/parquet/Indian Lounge.parquet',
#  '/project/parquet/Hard Rock Cafe.parquet',
#  '/project/parquet/The Peasant.parquet',
#  "/project/parquet/Scully St James's.parquet",
#  '/project/parquet/Indian Express.parquet',
#  "/project/parquet/Rudy's Neapolitan Pizza - Soho.parquet",
#  '/project/parquet/Monmouth Kitchen.parquet',
#  '/project/parquet/Bayleaf Restaurant.parquet',
#  '/project/parquet/Ô Gourmet Libanais.parquet',
#  '/project/parquet/Chettinad Restaurant.parquet',
#  '/project/parquet/Cappadocia Cafe & Bistro.parquet',
#  '/project/parquet/Grato.parquet',
#  '/project/parquet/Cafe Parisienne.parquet',
#  '/project/parquet/JW Steakhouse.parquet',
#  '/project/parquet/Dhaba@49.parquet',
#  '/project/parquet/Anjanaas.parquet',
#  '/project/parquet/Da Mario Covent Garden.parquet',
#  '/project/parquet/Laurent at Café Royal.parquet',
#  '/project/parquet/Scarlett Green.parquet',
#  '/project/parquet/Dalloway Terrace.parquet',
#  '/project/parquet/Constancia.parquet',
#  '/project/parquet/Dishoom Carnaby.parquet',
#  "/project/parquet/L'oro di Napoli Ealing.parquet",
#  '/project/parquet/Blacklock Shoreditch.parquet',
#  '/project/parquet/The Foyer & Reading Room.parquet',
#  "/project/parquet/Tania's Of Hampstead.parquet",
#  '/project/parquet/Little India.parquet',
#  '/project/parquet/Fish Central.parquet',
#  '/project/parquet/Smiths of Wapping.parquet',
#  '/project/parquet/Hazara Restaurants.parquet',
#  '/project/parquet/Llerena.parquet',
#  '/project/parquet/Revolution London - Putney.parquet',
#  '/project/parquet/Trinity.parquet',
#  '/project/parquet/Hiba Street Food.parquet',
#  '/project/parquet/Fast Break.parquet',
#  '/project/parquet/Everest Inn.parquet',
#  "/project/parquet/Sergio's.parquet",
#  '/project/parquet/ChoJo.parquet',
#  '/project/parquet/Mio Restaurant bar.parquet',
#  '/project/parquet/New London Cafe.parquet',
#  '/project/parquet/Iran Restaurant.parquet',
#  '/project/parquet/Humble Grape Islington.parquet',
#  '/project/parquet/Tomo Pizzeria-Restaurant.parquet',
#  '/project/parquet/Indian Moment.parquet',
#  '/project/parquet/Augustine Kitchen.parquet',
#  '/project/parquet/Revolution London - Clapham High St.parquet',
#  '/project/parquet/De Vine.parquet',
#  '/project/parquet/Memories of India Kensington.parquet',
#  '/project/parquet/Pizzetta.parquet',
#  '/project/parquet/Blighty - a very British cafe.parquet',
#  '/project/parquet/Ishtar.parquet',
#  '/project/parquet/PERA Bistro.parquet',
#  '/project/parquet/The Rajdoot Hampstead.parquet',
#  '/project/parquet/Chez Bruce.parquet',
#  '/project/parquet/Arro Coffee - Bayswater.parquet',
#  '/project/parquet/Salento Restaurant - Bar - pizzeria - Italian food grocery -.parquet',
#  '/project/parquet/Goodman - Mayfair.parquet',
#  '/project/parquet/Lentil Nepalese, Indian Cusine.parquet',
#  '/project/parquet/Bloomsbury Street Kitchen.parquet',
#  '/project/parquet/215 Hackney.parquet',
#  '/project/parquet/Bruce Burgers.parquet',
#  '/project/parquet/Dean Street Townhouse.parquet',
#  '/project/parquet/Brick Lane Brasserie.parquet',
#  '/project/parquet/Vincent Rooms.parquet',
#  '/project/parquet/Specialist Cellars.parquet',
#  '/project/parquet/Barge East Restaurant.parquet',
#  '/project/parquet/Ormer Mayfair Restaurant.parquet',
#  '/project/parquet/Almas Restaurant.parquet',
#  '/project/parquet/Leicester Square Kitchen.parquet',
#  '/project/parquet/Becks cafe.parquet',
#  '/project/parquet/The Hayden Pub & Rooms.parquet',
#  '/project/parquet/Bella Roma - Italian Restaurant.parquet',
#  '/project/parquet/Afternoon Tea at The Park Room.parquet',
#  '/project/parquet/Mangia Bene.parquet',
#  '/project/parquet/Dulce Coffee London.parquet',
#  '/project/parquet/Taste of Nawab.parquet',
#  '/project/parquet/The Chelsea Corner.parquet',
#  '/project/parquet/NORA CAFE.parquet',
#  '/project/parquet/Blacklock City.parquet',
#  '/project/parquet/May Fair Kitchen.parquet',
#  '/project/parquet/Blacklock Soho.parquet',
#  '/project/parquet/Steak & Lobster Warren Street.parquet',
#  '/project/parquet/The Cocktail Trading Co. Brick Lane.parquet',
#  "/project/parquet/L'Angolo Bianco.parquet",
#  '/project/parquet/Room 43 bar Clapham.parquet',
#  '/project/parquet/The Gojk Restaurant Lounge.parquet',
#  '/project/parquet/The Lounge Cafe Wembley.parquet',
#  '/project/parquet/Plate Restaurant.parquet',
#  "/project/parquet/Fiddie's.parquet",
#  '/project/parquet/Humble Grape Liverpool Street.parquet',
#  '/project/parquet/Yucca London.parquet',
#  '/project/parquet/Yum Sa.parquet',
#  '/project/parquet/Sky Pod Bar.parquet']

# %%
def get_variables(data):
    google_id = data['google_id']
    identifier = data['result']['name'].replace(" ", "").replace("'", "").replace("’", "").lower()
    restaurant_name = data['result']['name'].replace("'", "").replace("’", "")
    try:
        address = data['result']['formatted_address'].replace("'", "")
    except:
        address = 'no address'
    try:
        postcode = data['result']['address_components'][6]['long_name']
    except:
        postcode = 'no postcode'
    try:
        website = data['result']['website']
    except:
        website = 'no website'
    try:
        phone_number = data['result']['formatted_phone_number']
    except:
        phone_number = 'no phone number'
    try:
        opening_hours = str(data['result']['opening_hours']['weekday_text'])
    except:
        opening_hours = 'no opening hours'
    try:
        rating = data['result']['rating']
    except:
        rating = 'no rating'
    try:
        total_ratings = data['result']['user_ratings_total']
    except:
        total_ratings = 'no total ratings'
    try:
        price_level = data['result']['price_level']
    except:
        price_level = 'no price level'
    
    
    return google_id, identifier,restaurant_name, address, postcode, website, phone_number, rating, total_ratings, price_level

# %%
def etl(restaurant):
    df = spark.read.parquet(restaurant)
    json_data = json.loads(df.toJSON().first())
    
    table_name = 'public.google'
    sql_string = f'INSERT INTO {table_name}\nVALUES {get_variables(json_data)};'

    conn = connect(
        dbname = "initialdatabase",
        user = "yourname",
        host = "demsin0166.czfwea5noxbs.eu-west-2.rds.amazonaws.com",
        password = "password")
    
    cur = conn.cursor()
    
    try:
        cur.execute( sql_string )
        conn.commit()
        print(f'{restaurant} added to database')
    except:
        print(f'{restaurant} already in database')
    
    cur.close()
    conn.close()

# %%
for i in parquet_filepath:
    etl(i)
# Out:
# /project/parquet/Champagne Brunch at The Landmark London.parquet already in database
# /project/parquet/Zeret Kitchen.parquet added to database
# /project/parquet/Shahi Pakwaan.parquet added to database
# /project/parquet/Ciullosteria.parquet added to database
# /project/parquet/Buenos Aires.parquet already in database
# /project/parquet/Nonna Selena Pizzeria.parquet added to database
# /project/parquet/The India - Best of The City.parquet added to database
# /project/parquet/TOKii.parquet added to database
# /project/parquet/Trattoria Raffaele.parquet added to database
# /project/parquet/Figo Leyton.parquet added to database
# /project/parquet/Amber Restaurant.parquet added to database
# /project/parquet/Chez Abir Lebanese Restaurant.parquet already in database
# /project/parquet/The Bull Steak Expert.parquet added to database
# /project/parquet/Core by Clare Smyth.parquet added to database
# /project/parquet/Lorne.parquet already in database
# /project/parquet/EaTurkish.parquet added to database
# /project/parquet/Indian Room.parquet already in database
# /project/parquet/Lord Wargrave.parquet added to database
# /project/parquet/The Ledbury.parquet added to database
# /project/parquet/Bel Canto.parquet already in database
# /project/parquet/Bengal Village - Best of Brick Lane.parquet added to database
# /project/parquet/Dobar.parquet already in database
# /project/parquet/Featherblade Steak Restaurant.parquet already in database
# /project/parquet/Fishcotheque.parquet added to database
# /project/parquet/The Pride of Spitalfields London.parquet already in database
# /project/parquet/The Clink Brixton.parquet already in database
# /project/parquet/Muhib Indian cuisine.parquet already in database
# /project/parquet/28-50 Wine Workshop & Kitchen.parquet already in database
# /project/parquet/Kahani Restaurant Sloane Square.parquet already in database
# /project/parquet/Peninsula Restaurant.parquet added to database
# /project/parquet/Luna Rossa.parquet added to database
# /project/parquet/Sam's Riverside.parquet added to database
# /project/parquet/Azou Restaurant.parquet already in database
# /project/parquet/Bar Remo.parquet added to database
# /project/parquet/The Great Chase.parquet already in database
# /project/parquet/Wolkite restaurant.parquet added to database
# /project/parquet/Bella Vita.parquet added to database
# /project/parquet/Il Girasole restaurant.parquet already in database
# /project/parquet/taNgia.parquet added to database
# /project/parquet/The Jasmine By Spice Nouv-Oh!.parquet added to database
# /project/parquet/Sanjugo Shoreditch.parquet already in database
# /project/parquet/Fugitive Motel.parquet added to database
# /project/parquet/Prince of Wales, Brixton.parquet already in database
# /project/parquet/Radicals And Victuallers.parquet added to database
# /project/parquet/Chisou Sushi and Izakaya.parquet already in database
# /project/parquet/The Rajdoot.parquet already in database
# /project/parquet/Kings Stores.parquet added to database
# /project/parquet/TANAKATSU.parquet added to database
# /project/parquet/Galvin La Chapelle.parquet added to database
# /project/parquet/Lizzie's Cucina - Italian Restaurant.parquet already in database
# /project/parquet/The Rosebery.parquet added to database
# /project/parquet/Awesome Thai #Finchley.parquet already in database
# /project/parquet/Little Wonder Cafe.parquet added to database
# /project/parquet/Magic Falafel.parquet added to database
# /project/parquet/Mildreds Camden.parquet added to database
# /project/parquet/Flora Indica.parquet added to database
# /project/parquet/Humble Grape.parquet added to database
# /project/parquet/Amrutha Lounge.parquet already in database
# /project/parquet/Wolf+Spoon.parquet already in database
# /project/parquet/Turtle Bay Brixton.parquet already in database
# /project/parquet/Lanes of London.parquet added to database
# /project/parquet/Katakata.parquet added to database
# /project/parquet/London Shell Co..parquet already in database
# /project/parquet/Wassouf Lounge.parquet added to database
# /project/parquet/Pizza Sophia.parquet added to database
# /project/parquet/Zala grill.parquet added to database
# /project/parquet/CERU South Kensington.parquet already in database
# /project/parquet/Bella Italia - Cranbourn Street.parquet already in database
# /project/parquet/Light Of India.parquet added to database
# /project/parquet/Flour to the People!.parquet added to database
# /project/parquet/The Five Fields.parquet added to database
# /project/parquet/The Hampshire.parquet added to database
# /project/parquet/Bebs Kitchen.parquet added to database
# /project/parquet/The Famous Curry Bazaar.parquet added to database
# /project/parquet/Oi Vita Pizzeria.parquet added to database
# /project/parquet/Pivaz.parquet already in database
# /project/parquet/Compañero.parquet already in database
# /project/parquet/Seven Park Place by William Drabble.parquet added to database
# /project/parquet/The Union Tavern.parquet already in database
# /project/parquet/Rock Star Sushi Bar.parquet added to database
# /project/parquet/Cafe de Provence.parquet added to database
# /project/parquet/Casa Tua Camden.parquet added to database
# /project/parquet/Liman Restaurant.parquet added to database
# /project/parquet/Tower Tandoori Restaurant.parquet already in database
# /project/parquet/The Swan.parquet added to database
# /project/parquet/The Prince of Greenwich Pub.parquet added to database
# /project/parquet/Frog by Adam Handling Restaurant Covent Garden.parquet already in database
# /project/parquet/Osteria Napoletana.parquet added to database
# /project/parquet/Hibox.parquet already in database
# /project/parquet/Pentolina.parquet added to database
# /project/parquet/Monkey Temple.parquet added to database
# /project/parquet/Salut! Restaurant Islington.parquet already in database
# /project/parquet/Miller Group Limited.parquet already in database
# /project/parquet/The Monsoon.parquet added to database
# /project/parquet/B Bagel Fulham.parquet already in database
# /project/parquet/E Pellicci.parquet added to database
# /project/parquet/Flat Iron London Bridge.parquet added to database
# /project/parquet/Myrtle Restaurant.parquet added to database
# /project/parquet/Cirrik 19 Numara Bos.parquet added to database
# /project/parquet/The Victoria, Paddington.parquet already in database
# /project/parquet/The Bar.parquet already in database
# /project/parquet/Popolo Shoreditch.parquet added to database
# /project/parquet/Wild Thyme Cafe.parquet already in database
# /project/parquet/Tonis Amalfi Italian Restaurant & Pizzeria.parquet already in database
# /project/parquet/Alcedo Bistro & Bar.parquet added to database
# /project/parquet/Terra Rossa.parquet added to database
# /project/parquet/Mountain view.parquet already in database
# /project/parquet/Golden Chippy.parquet already in database
# /project/parquet/Chez Antoinette Victoria.parquet added to database
# /project/parquet/Le Petit Citron.parquet added to database
# /project/parquet/Alexandrie Restaurant.parquet added to database
# /project/parquet/Kazan Restaurant.parquet added to database
# /project/parquet/Panas Gurkha Restaurant.parquet added to database
# /project/parquet/Double J'S Cafe.parquet added to database
# /project/parquet/Niche Gluten-free Dining.parquet added to database
# /project/parquet/Las Iguanas - London - The O2.parquet already in database
# /project/parquet/Falafel Feast.parquet added to database
# /project/parquet/La Piccola Deli Pasticceria.parquet added to database
# /project/parquet/Treves (UK) Ltd.parquet already in database
# /project/parquet/Pane Cunzato - Italian Pizza Restaurant.parquet already in database
# /project/parquet/Gloria.parquet added to database
# /project/parquet/Caminata.parquet added to database
# /project/parquet/Sapori.parquet already in database
# /project/parquet/Nepal Authentic Dining.parquet added to database
# /project/parquet/Nipa Thai.parquet already in database
# /project/parquet/Fine Foods - Locanda del Melo.parquet already in database
# /project/parquet/Taste of India NW1.parquet already in database
# /project/parquet/Oliveira Kitchen.parquet added to database
# /project/parquet/Khan's of Kensington.parquet added to database
# /project/parquet/Richard’s Kitchen.parquet added to database
# /project/parquet/Chez Elles Bistroquet.parquet added to database
# /project/parquet/Standard Balti House.parquet already in database
# /project/parquet/Tom Simmons - Tower Bridge.parquet added to database
# /project/parquet/AW Restaurant.parquet added to database
# /project/parquet/The Petite Corée.parquet already in database
# /project/parquet/Alexander The Great Restaurant.parquet already in database
# /project/parquet/Launceston Place.parquet already in database
# /project/parquet/Anglo.parquet added to database
# /project/parquet/Manuel's Italian and Mediterranean Restaurant and Bar.parquet already in database
# /project/parquet/Moira Restaurant.parquet added to database
# /project/parquet/Sushi Tetsu.parquet added to database
# /project/parquet/La Trompette.parquet added to database
# /project/parquet/Andy’s Greek Taverna.parquet already in database
# /project/parquet/Café Amisha.parquet already in database
# /project/parquet/Volare.parquet added to database
# /project/parquet/Baileys.parquet already in database
# /project/parquet/Wiltons Restaurant.parquet already in database
# /project/parquet/Mosob Restaurant.parquet added to database
# /project/parquet/Maurizio Barca.parquet added to database
# /project/parquet/Capeesh.parquet added to database
# /project/parquet/The Wine Place Covent Garden.parquet already in database
# /project/parquet/Yuu Kitchen.parquet added to database
# /project/parquet/The Oystermen Seafood Bar & Kitchen.parquet added to database
# /project/parquet/Morso Abbey Road.parquet added to database
# /project/parquet/Filika Restaurant.parquet added to database
# /project/parquet/Otto's French Restaurant London.parquet already in database
# /project/parquet/Spasso.parquet already in database
# /project/parquet/Luna Nuova.parquet added to database
# /project/parquet/Daphne Restaurant.parquet added to database
# /project/parquet/Palms of Goa.parquet added to database
# /project/parquet/Kona.parquet added to database
# /project/parquet/Cafe Van Gogh.parquet added to database
# /project/parquet/The Blacksmiths Arms.parquet added to database
# /project/parquet/Purezza Camden.parquet added to database
# /project/parquet/Jolie - French Restaurant, Brunch & Terrace.parquet already in database
# /project/parquet/Pure Indian cooking.parquet added to database
# /project/parquet/Bonoo Indian Tapas.parquet already in database
# /project/parquet/The Wilmington.parquet added to database
# /project/parquet/The Shell.parquet added to database
# /project/parquet/Mestizo Mexican Restaurant.parquet already in database
# /project/parquet/Après Food for Body and Mind.parquet already in database
# /project/parquet/Limin' Beach Club.parquet already in database
# /project/parquet/Home SW15.parquet added to database
# /project/parquet/The Sitara.parquet already in database
# /project/parquet/Paladar.parquet already in database
# /project/parquet/Food at Fishers Ltd.parquet already in database
# /project/parquet/MAP Maison.parquet added to database
# /project/parquet/Osteria Romana.parquet added to database
# /project/parquet/The Banc.parquet added to database
# /project/parquet/Latitude Restaurant.parquet already in database
# /project/parquet/Kamasutra Indian Restaurant.parquet added to database
# /project/parquet/The Spice.parquet already in database
# /project/parquet/Rossella.parquet added to database
# /project/parquet/Kibele Restaurant.parquet already in database
# /project/parquet/RodFai.parquet already in database
# /project/parquet/Bar 61 Restaurant.parquet added to database
# /project/parquet/The White Onion.parquet added to database
# /project/parquet/The Little Taperia.parquet added to database
# /project/parquet/Pizza Pilgrims.parquet added to database
# /project/parquet/Boro Bistro.parquet added to database
# /project/parquet/Iznik.parquet added to database
# /project/parquet/El Inca Plebeyo Restaurant.parquet already in database
# /project/parquet/Medlar.parquet added to database
# /project/parquet/Eastern Eye Balti House.parquet already in database
# /project/parquet/Cibo.parquet added to database
# /project/parquet/Chamisse.parquet already in database
# /project/parquet/Hungry Turtle.parquet added to database
# /project/parquet/Senzala Creperie.parquet added to database
# /project/parquet/Midpoint Restaurant.parquet added to database
# /project/parquet/Knife.parquet already in database
# /project/parquet/Venerdi.parquet added to database
# /project/parquet/Indian Lounge.parquet added to database
# /project/parquet/Hard Rock Cafe.parquet already in database
# /project/parquet/The Peasant.parquet added to database
# /project/parquet/Scully St James's.parquet added to database
# /project/parquet/Indian Express.parquet already in database
# /project/parquet/Rudy's Neapolitan Pizza - Soho.parquet already in database
# /project/parquet/Monmouth Kitchen.parquet already in database
# /project/parquet/Bayleaf Restaurant.parquet already in database
# /project/parquet/Ô Gourmet Libanais.parquet already in database
# /project/parquet/Chettinad Restaurant.parquet added to database
# /project/parquet/Cappadocia Cafe & Bistro.parquet already in database
# /project/parquet/Grato.parquet added to database
# /project/parquet/Cafe Parisienne.parquet already in database
# /project/parquet/JW Steakhouse.parquet added to database
# /project/parquet/Dhaba@49.parquet added to database
# /project/parquet/Anjanaas.parquet added to database
# /project/parquet/Da Mario Covent Garden.parquet added to database
# /project/parquet/Laurent at Café Royal.parquet already in database
# /project/parquet/Scarlett Green.parquet already in database
# /project/parquet/Dalloway Terrace.parquet added to database
# /project/parquet/Constancia.parquet added to database
# /project/parquet/Dishoom Carnaby.parquet added to database
# /project/parquet/L'oro di Napoli Ealing.parquet already in database
# /project/parquet/Blacklock Shoreditch.parquet added to database
# /project/parquet/The Foyer & Reading Room.parquet already in database
# /project/parquet/Tania's Of Hampstead.parquet already in database
# /project/parquet/Little India.parquet added to database
# /project/parquet/Fish Central.parquet added to database
# /project/parquet/Smiths of Wapping.parquet already in database
# /project/parquet/Hazara Restaurants.parquet already in database
# /project/parquet/Llerena.parquet already in database
# /project/parquet/Revolution London - Putney.parquet already in database
# /project/parquet/Trinity.parquet already in database
# /project/parquet/Hiba Street Food.parquet already in database
# /project/parquet/Fast Break.parquet added to database
# /project/parquet/Everest Inn.parquet already in database
# /project/parquet/Sergio's.parquet added to database
# /project/parquet/ChoJo.parquet added to database
# /project/parquet/Mio Restaurant bar.parquet already in database
# /project/parquet/New London Cafe.parquet added to database
# /project/parquet/Iran Restaurant.parquet added to database
# /project/parquet/Humble Grape Islington.parquet added to database
# /project/parquet/Tomo Pizzeria-Restaurant.parquet already in database
# /project/parquet/Indian Moment.parquet already in database
# /project/parquet/Augustine Kitchen.parquet added to database
# /project/parquet/Revolution London - Clapham High St.parquet already in database
# /project/parquet/De Vine.parquet already in database
# /project/parquet/Memories of India Kensington.parquet added to database
# /project/parquet/Pizzetta.parquet already in database
# /project/parquet/Blighty - a very British cafe.parquet already in database
# /project/parquet/Ishtar.parquet added to database
# /project/parquet/PERA Bistro.parquet already in database
# /project/parquet/The Rajdoot Hampstead.parquet already in database
# /project/parquet/Chez Bruce.parquet added to database
# /project/parquet/Arro Coffee - Bayswater.parquet added to database
# /project/parquet/Salento Restaurant - Bar - pizzeria - Italian food grocery -.parquet already in database
# /project/parquet/Goodman - Mayfair.parquet already in database
# /project/parquet/Lentil Nepalese, Indian Cusine.parquet already in database
# /project/parquet/Bloomsbury Street Kitchen.parquet added to database
# /project/parquet/215 Hackney.parquet added to database
# /project/parquet/Bruce Burgers.parquet already in database
# /project/parquet/Dean Street Townhouse.parquet already in database
# /project/parquet/Brick Lane Brasserie.parquet added to database
# /project/parquet/Vincent Rooms.parquet already in database
# /project/parquet/Specialist Cellars.parquet added to database
# /project/parquet/Barge East Restaurant.parquet added to database
# /project/parquet/Ormer Mayfair Restaurant.parquet already in database
# /project/parquet/Almas Restaurant.parquet added to database
# /project/parquet/Leicester Square Kitchen.parquet added to database
# /project/parquet/Becks cafe.parquet added to database
# /project/parquet/The Hayden Pub & Rooms.parquet already in database
# /project/parquet/Bella Roma - Italian Restaurant.parquet added to database
# /project/parquet/Afternoon Tea at The Park Room.parquet already in database
# /project/parquet/Mangia Bene.parquet added to database
# /project/parquet/Dulce Coffee London.parquet already in database
# /project/parquet/Taste of Nawab.parquet already in database
# /project/parquet/The Chelsea Corner.parquet added to database
# /project/parquet/NORA CAFE.parquet already in database
# /project/parquet/Blacklock City.parquet added to database
# /project/parquet/May Fair Kitchen.parquet added to database
# /project/parquet/Blacklock Soho.parquet added to database
# /project/parquet/Steak & Lobster Warren Street.parquet already in database
# /project/parquet/The Cocktail Trading Co. Brick Lane.parquet already in database
# /project/parquet/L'Angolo Bianco.parquet added to database
# /project/parquet/Room 43 bar Clapham.parquet already in database
# /project/parquet/The Gojk Restaurant Lounge.parquet already in database
# /project/parquet/The Lounge Cafe Wembley.parquet already in database
# /project/parquet/Plate Restaurant.parquet already in database
# /project/parquet/Fiddie's.parquet already in database
# /project/parquet/Humble Grape Liverpool Street.parquet added to database
# /project/parquet/Yucca London.parquet already in database
# /project/parquet/Yum Sa.parquet added to database
# /project/parquet/Sky Pod Bar.parquet added to database
